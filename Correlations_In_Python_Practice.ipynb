# %% [markdown]
# #### Correlation
# Correlations can be done on two continuous variables, to determine the relationship between them. As a reminder, a correlation can be between zero and one, and either positive or negative. The larger it is, the more closely related the two variables are.

# %%
Import Packages
In addition to the usual pandas, you will also need to import pyplot and seaborn to be able to graphically visualize correlations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Import Data and view

# %%
CruiseShip = pd.read_csv('C:/Users/desja/python_course/datasets/CruiseShip.csv')
CruiseShip.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab
# 0     42.64     329
# 1     42.64     329
# 2     31.80     453
# 3     36.99     892
# 4     38.36     740

# %% [markdown]
# #### Run One Correlation
# Using the function .corr(), it's easy to run a correlation on a selected two variables.
#
# #### Requirement
# For instance, do you think that the number of passengers and the number of cabins on a cruise ship would relate to each other?
#
# The first thing you type is one of your variables, then you call .corr() and list the second variable.

# %%
CruiseShip['passngrs'].corr(CruiseShip['Cabins'])
# Out:
# 0.9763413679845939

# %% [markdown]
# #### Output:
# It should not come as a surprise to you that the number of passengers and the number of cabins are very related. .97 is about as strong as a correlation gets! This correlation is also positive, which means that as the number of passengers increase, so does the number of cabins, and vice versa.

# %% [markdown]
# #### Create a Correlation Matrix
# Running one correlation can be nice, but sometimes you'd like to know how all your data relates to each other! In that case, call in the big guns, and go for a correlation matrix!

# %% [markdown]
# #### Drop Non-Continuous Variables
# When you are creating a correlation matrix, you are feeding the code your entire data set.
#
# #### Note:
# But you can only run Pearson's correlations on continuous variables! So it's important to drop anything that is categorical or a string first.
#
# the .drop() function will remove any columns specified in the square brackets, and the axis=1 arguments tells Python that these are the names of columns (not rows). So you are getting rid of the Ship and Line columns here.

# %%
CruiseShip1 = CruiseShip.drop(['Ship', 'Line'], axis=1)
CruiseShip1.head()
# Out:
#    YearBlt  Tonnage  passngrs  Length  Cabins  Crew  PassSpcR  outcab
# 0     2007    30277       694     594     355   355     42.64     329
# 1     2007    30277       694     594     355   355     42.64     329
# 2     1987    47262      1486     722     743   670     31.80     453
# 3     2002   110000      2974     953    1488  1910     36.99     892
# 4     1996   101353      2642     892    1321  1000     38.36     740

# %% [markdown]
# #### Using .corr() on An Entire Dataset
# You will not believe how easy it is to get all correlations at your fingertips!

# %%
CruiseShip1.corr(method='pearson')
# Out:
#            YearBlt   Tonnage  passngrs    Length    Cabins      Crew  \
# YearBlt   1.000000  0.606646  0.515542  0.532286  0.510019  0.530657
# Tonnage   0.606646  1.000000  0.945061  0.922368  0.948764  0.927569
# passngrs  0.515542  0.945061  1.000000  0.883535  0.976341  0.915234
# Length    0.532286  0.922368  0.883535  1.000000  0.889798  0.895857
# Cabins    0.510019  0.948764  0.976341  0.889798  1.000000  0.950823
# Crew      0.530657  0.927569  0.915234  0.895857  0.950823  1.000000
# PassSpcR  0.278830 -0.040846 -0.294867 -0.090488 -0.253181 -0.155509
# outcab    0.547203  0.921931  0.914551  0.901047  0.934136  0.900466
#
#           PassSpcR    outcab
# YearBlt   0.278830  0.547203
# Tonnage  -0.040846  0.921931
# passngrs -0.294867  0.914551
# Length   -0.090488  0.901047
# Cabins   -0.253181  0.934136
# Crew     -0.155509  0.900466
# PassSpcR  1.000000 -0.145602
# outcab   -0.145602  1.000000

# %% [markdown]
# #### Output
# Remember that you read only the top right or bottom left of this matrix; everything repeats after the diagonal row of ones.

# %% [markdown]
# #### Make .corr() Pretty!

# %%
CruiseShip1.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style type="text/css">
# #T_6ebce_row0_col0, #T_6ebce_row1_col1, #T_6ebce_row2_col2, #T_6ebce_row3_col3, #T_6ebce_row4_col4, #T_6ebce_row5_col5, #T_6ebce_row6_col6, #T_6ebce_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6ebce_row0_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_6ebce_row0_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_6ebce_row0_col3, #T_6ebce_row0_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_6ebce_row0_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_6ebce_row0_col6, #T_6ebce_row1_col6, #T_6ebce_row2_col6, #T_6ebce_row3_col6, #T_6ebce_row4_col6, #T_6ebce_row5_col6, #T_6ebce_row6_col2, #T_6ebce_row7_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6ebce_row0_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_6ebce_row1_col0 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_6ebce_row1_col2, #T_6ebce_row4_col7 {
# ...

# %% [markdown]
# #### Use sns.heatmap()
# You can also do a correlation matrix easily using the seaborn package:

# %%
sns.heatmap(CruiseShip1.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Summary
# In this lesson, I learned how to perform all the basic statistics I have learned in MS Excel and R, including t-tests, Chi-Squares, and correlations. It is important that I become proficient with the basics in all three languages!
